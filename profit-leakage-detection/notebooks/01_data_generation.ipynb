# %% [markdown]
# # 01 — Data Generation & Validation
# Significance: realistic seasonality, regional shocks, and technician anomalies to test profit leakage detection.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
df = pd.read_csv('../data/service_orders_synthetic.csv', parse_dates=['order_dt'])
df.head()

# %%
df.info()
df.describe(include='all').T.head(25)

# %%
plt.figure(); plt.hist(df['margin_pct'].dropna(), bins=60); plt.title('Margin % Distribution'); plt.show()
